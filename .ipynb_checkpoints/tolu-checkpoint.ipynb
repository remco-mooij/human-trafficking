# %%
import pandas as pd
import pycountry
import PyPDF2 
import textract
import re

# %%
# Initialize list sequence to store names of Countries
countries = [
    'Afghanistan','Albania','Algeria','Angola','Antigua and Barbuda',
    'Argentina','Armenia','Aruba','Australia','Austria','Azerbaijan',
    'The Bahamas','Bahrain','Bangladesh','Barbados','Belarus','Belgium', 
    'Belize','Benin','Bhutan','Bolivia','Bosnia and Herzegovina',
    'Botswana','Brazil','Brunei','Bulgaria','Burkina Faso','Burma',
    'Burundi','Cabo Verde','Cambodia','Cameroon','Canada','Central African Republic',
    'Chad','Chile','China','Colombia','Comoros','Congo, Democratic Republic of the',
    'Congo, Republic of the','Costa Rica',"Cote d'Ivoire",'Croatia','Cuba','Curaçao',
    'Cyprus','Czech Republic', 'Denmark','Djibouti', 'Dominican Republic','Ecuador',
    'Egypt','El Salvador','Equatorial Guinea', 'Eritrea','Estonia','Eswatini','Ethiopia',
    'Fiji', 'Finland', 'France','Gabon','The Gambia','Georgia','Germany','Ghana','Greece',
    'Guatemala','Guinea','Guinea-Bissau','Guyana','Haiti','Honduras','Hong Kong','Hungary',
    'Iceland','India','Indonesia','Iran','Iraq','Ireland','Israel','Italy','Jamaica','Japan',
    'Jordan','Kazakhstan','Kenya',"Korea, Democratic People's Republic of",'Korea, Republic of',
    'Kosovo','Kuwait','Kyrgyz Republic',"Laos",'Latvia','Lebanon','Lesotho','Liberia','Lithuania',
    'Luxembourg','Macau','Macedonia','Madagascar','Malawi','Malaysia','Maldives','Mali','Malta',
    'Marshall Islands','Mauritania','Mauritius','Mexico','Micronesia, Federated States of',
    'Moldova','Mongolia','Montenegro','Morocco','Mozambique','Namibia','Nepal','Netherlands',
    'New Zealand','Nicaragua','Niger','Nigeria','Norway','Oman','Pakistan','Palau','Panama',
    'Papua Guinea New','Paraguay','Peru','Philippines','Poland','Portugal','Qatar','Romania',
    'Russia','Rwanda','St. Lucia','St. Vincent and the Grenadines','Saudi Arabia','Senegal','Serbia',
    'Seychelles','Sierra Leone','Singapore','Slovakia','Slovenia','Solomon Islands','South Africa',
    'South Sudan','Spain','Sri Lanka','Sudan','Suriname','Sweden','Switzerland','Syria','Taiwan',
    'Tajikistan','Tanzania','Thailand','Timor-Leste','Togo','Tonga','Trinidad and Tobago','Tunisia',
    'Turkey','Turkmenistan','Uganda','Ukraine','United Arab Emirates','United Kingdom',
    'United States of America','Uruguay','Uzbekistan','Venezuela', 'Vietnam','Zambia','Zimbabwe',
    'Libya','St. Maarten','Somalia','Yemen' #Libya, St. Marteen, Somalia and Yemen are Special Cases
]

# %%
len(countries)
# Out:
# 187

# %%
# Function to Parse the pdf file
def parse_file(filename): 
    # Read the file.
    pdfFileObj = open(filename,'rb')
    # The pdfReader variable is the readable object that will be parsed.
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
    #Parse through all the pages.
    num_pages = pdfReader.numPages
    count = 0
    text = ""
    # The while loop will read each page.
    while count < num_pages:
        pageObj = pdfReader.getPage(count)
        count +=1
        text += pageObj.extractText()
    # This if statement exists to check if the above library returned words. It's done because PyPDF2 cannot read scanned files.
    if text != "":
        text = text
    # If the above returns as False, run the OCR library textract to #convert scanned/image based PDF files into text.
    else:
        text = textract.process(fileurl, method='tesseract', language='eng')
    return text

text = parse_file('2018-TIP-Report.pdf')

# %%
# Function to Clean the parsed pdf
def clean_text(text):
    text = text.strip().replace("\n", "").replace("˜", "fi").replace("˚", "ft").replace("Sincerely,iiiiii","")\
                .replace("Trafiick","Traffick").replace("™", "'").replace("trafiick","traffick")\
                .replace('ﬁprevalence rateﬂ','"prevalence rate"').replace("˚ight","fight")\
                .replace("/", "").replace("  REPUBLIC OF THE:", " REPUBLIC OF THE:")\
                .replace("DEMOCRATIC PEOPLE'S  REPUBLIC OF", "DEMOCRATIC PEOPLE'S REPUBLIC OF")\
                .replace("PAPUA NEW GUINEA:", "PAPUA GUINEA NEW:").replace("⁄", "").replace("\\","")\
                .replace("ST. VINCENT AND  THE GRENADINES", "ST. VINCENT AND THE GRENADINES")\
                .replace("UNITED STATES  OF AMERICA", "UNITED STATES OF AMERICA")\
                .replace("461SPECIAL CASE: LIBYA", " ").replace("462SPECIAL CASE: LIBYA", " ")\
                .replace("463SPECIAL CASE: ST. MAARTEN", " ").replace("464SPECIAL CASE: SOMALIA", " ")\
                .replace("465SPECIAL CASE: SOMALIA", " ").replace("466SPECIAL CASE: YEMEN", " ")\
                .replace("467SPECIAL CASE: YEMEN", " ").replace("468SPECIAL CASE: YEMEN", " ")
    return text 

cleaned_text = clean_text(text)

# %%
# Function to Extract each country data from text
def extract_info(countries_list,text):
    # Create list to query info for each country
    countries_up = []
    for i in countries:
        if i in ["Libya", 'St. Maarten', 'Somalia', 'Yemen']:
            countries_up.append("SPECIAL CASE: "+i.upper())
        else: 
            countries_up.append(i.upper()+":")        
    new_list = []
    a = text.split(countries_up[0])
    for i in range(len(countries_up)-1):
        a = a[1].split(countries_up[i+1])
        new_list.append(a[0])
        if i+1 == len(countries_up)-1:
            new_list.append(a[1].split("469RELEVANT INTERNATIONAL CONVENTIONS")[0])
    return new_list

country_info = extract_info(countries,cleaned_text)
len(country_info)
# Out:
# 187

# %%
# Function to Extract each country data from text
def extract_info(countries_list,text):
    # Create list to query info for each country
    countries_up = []
    for i in countries:
        if i in ["Libya", 'St. Maarten', 'Somalia', 'Yemen']:
            countries_up.append("SPECIAL CASE: "+i.upper())
        else: 
            countries_up.append(i.upper()+":")
    new_list = []
    a = text.split(countries_up[0])
    for i in range(len(countries_up)-1):
        a = a[1].split(countries_up[i+1])
        new_list.append(a[0])
        if i+1 == len(countries_up)-1:
            new_list.append(a[1].split("469RELEVANT INTERNATIONAL CONVENTIONS")[0])
    return new_list

country_info = extract_info(countries,cleaned_text)
len(country_info)
# Out:
# 187

# %%
country_dict = {i.upper():[{j:k}] for i,j,k in zip(countries, ["INTRO"]*187, country_info)}
special = [s.upper() for s in ['Libya','St. Maarten','Somalia','Yemen']]
special_country_dict = {s:country_dict[s] for s in special}
print(len(country_dict.values()))
print(len(special_country_dict))
# Out:
# 187
# 4

# %%
def removekey(d,delete_items):
    r = dict(d)
    for key in delete_items: 
        del r[key]
    return r

normal_country_dict = removekey(country_dict, special)
print(len(normal_country_dict.values()))
normal_countr = list(normal_country_dict.keys())
# Out:
# 183

# %%
def append_data(country,i,data):
    data[0]["INTRO"] = data[0]["INTRO"].split(i)[1]
    data.append({"TIER":i})
    intro = data[0]["INTRO"].split(f"RECOMMENDATIONS FOR {country}")
    data[0]["INTRO"] = intro[0]
    recommend = intro[1].split("PROSECUTION")
    data.append({"RECOMMENDATIONS":recommend[0]})
    prosecute = recommend[1].split("PROTECTION")
    data.append({"PROSECUTIONS":prosecute[0]})
    protect = prosecute[1].split("PREVENTION")
    data.append({"PROTECTION":protect[0]})
    prevent = protect[1].split("TRAFFICKING PROFILE")
    data.append({"PREVENTION":prevent[0]})
    data.append({"TRAFFICKING PROFILE":prevent[1]})
    return data

# %%
def portion_data(country):
    data = normal_country_dict[country]
    tier = ["TIER 1", "TIER 2", "TIER 3"]
    for i in tier:
        length = len(data[0]["INTRO"].split(i))       
        if "TIER 2 WATCH LIST" in data[0]["INTRO"]:
            i = "TIER 2 WATCH LIST"
            append_data(country,i,data)
        elif length == 2 and "TIER 2 WATCH LIST" not in data[0]["INTRO"]: 
            append_data(country,i,data)            
    return data,country_dict

# %%
x = countries[:183]  #183
new_normal_dict = [{i.upper():portion_data(i.upper())[0]} for i in x]

# %%
def get_country_special(country):
    new_special = []
    intro = special_country_dict[country][0]["INTRO"].split("GOVERNMENT EFFORTS")
    new_special.append({"INTRO":intro[0]})
    new_special.append({"TIER": "SPECIAL CASE"})
    traffick = intro[1].split("TRAFFICKING PROFILE")
    new_special.append({"GOVERNMENT EFFORTS":traffick[0]})
    new_special.append({"TRAFFICKING PROFILE":traffick[1]})
    return new_special

# %%
special = [i.upper() for i in ["Libya", 'St. Maarten', 'Somalia', 'Yemen']]
new_special_dict = [{i:get_country_special(i)} for i in special]

# %%
def get_traffic_profile(country_list,country_dict):
    return [{a:list(country_dict[country_list.index(a)][a][-1].values())[0]} for a,b in zip(country_list, country_dict)]

# %%
normal_trafficking_profile = get_traffic_profile(normal_countr,new_normal_dict)
special_trafficking_profile = get_traffic_profile(special,new_special_dict)

# %%
special_trafficking_profile = get_traffic_profile(special,new_special_dict)
trafficking_profile = normal_trafficking_profile.copy()
trafficking_profile.extend(special_trafficking_profile)

# %%
new_normal_countr = normal_countr.copy()
new_normal_countr.extend(special)

# %%
changed_countries = [
    'Afghanistan','Albania','Algeria','Angola','Antigua and Barbuda',
    'Argentina','Armenia','Aruba','Australia','Austria','Azerbaijan',
    'The Bahamas','Bahrain','Bangladesh','Barbados','Belarus','Belgium', 
    'Belize','Benin','Bhutan','Bolivia','Bosnia and Herzegovina',
    'Botswana','Brazil','Brunei','Bulgaria','Burkina Faso','Burma',
    'Burundi','Cabo Verde','Cambodia','Cameroon','Canada','Central African Republic',
    'Chad','Chile','China','Colombia','Comoros','Democratic',
    'Republic of The Congo','Costa Rica',"Cote d'Ivoire",'Croatia','Cuba','Curaçao',
    'Cyprus','Czech Republic', 'Denmark','Djibouti', 'Dominican Republic','Ecuador',
    'Egypt','El Salvador','Equatorial Guinea', 'Eritrea','Estonia','Eswatini','Ethiopia',
    'Fiji', 'Finland', 'France','Gabon','The Gambia','Georgia','Germany','Ghana','Greece',
    'Guatemala','Guinea','Guinea-Bissau','Guyana','Haiti','Honduras','Hong Kong','Hungary',
    'Iceland','India','Indonesia','Iran','Iraq','Ireland','Israel','Italy','Jamaica','Japan',
    'Jordan','Kazakhstan','Kenya',"North Korea",'South Korea',
    'Kosovo','Kuwait','Kyrgyz Republic',"Laos",'Latvia','Lebanon','Lesotho','Liberia','Lithuania',
    'Luxembourg','Macau','Macedonia','Madagascar','Malawi','Malaysia','Maldives','Mali','Malta',
    'Marshall Islands','Mauritania','Mauritius','Mexico','Micronesia','Moldova','Mongolia',
    'Montenegro','Morocco','Mozambique','Namibia','Nepal','Netherlands','New Zealand','Nicaragua',
    'Niger','Nigeria','Norway','Oman','Pakistan','Palau','Panama','Papua Guinea New','Paraguay',
    'Peru','Philippines','Poland','Portugal','Qatar','Romania','Russia','Rwanda','St. Lucia',
    'St. Vincent and the Grenadines','Saudi Arabia','Senegal','Serbia','Seychelles','Sierra Leone',
    'Singapore','Slovakia','Slovenia','Solomon Islands','South Africa','South Sudan','Spain',
    'Sri Lanka','Sudan','Suriname','Sweden','Switzerland','Syria','Taiwan','Tajikistan','Tanzania',
    'Thailand','Timor-Leste','Togo','Tonga','Trinidad and Tobago','Tunisia','Turkey','Turkmenistan',
    'Uganda','Ukraine','United Arab Emirates','United Kingdom','United States','Uruguay',
    'Uzbekistan','Venezuela', 'Vietnam','Zambia','Zimbabwe','Libya','St. Maarten','Somalia','Yemen' 
    #Libya, St. Marteen, Somalia and Yemen are Special Cases
]

# %%
def get_dataframe(countries,country_list,trafficking_profile):
    x = 0
    j = {
        "Base Country":[],
        "Relation Country":[],
        "Men": [],
        "Women":[],
        "Children":[],
        "Sex Trafficking":[],
        "Forced Labor":[],
        "Debt Bondage":[],
        "Description":[]
        }
    for country in country_list:
        a = list(trafficking_profile[x].values())[0].split(".")
        a = a[:len(a)-1]
        strip_country = countries.copy()
        d = strip_country.pop(country_list.index(country))   
        for b in a:
            for i in strip_country:
                if i in b:
                    if "men" in b or "women" in b or "boy" in b or "girl" in b or "child" in b or "Men" in b or "Women" in b or "Boy" in b or "Girl" in b or "Child" in b:
                        j["Relation Country"].append(i)
                        j["Base Country"].append(d)
                        j["Description"].append(b)
                        if "women" not in b and "Women" not in b and "men" in b or "Men" in b:
                                j["Men"].append(1)
                        else:
                            j["Men"].append(0)
                        if "women" in b or "Women" in b:
                            j["Women"].append(1)
                        else:
                            j["Women"].append(0)
                        if "boy" in b or "girl" in b or "child" in b or "Boy" in b or "Girl" in b or "Child" in b:
                            j["Children"].append(1)
                        else:
                            j["Children"].append(0)
                        if "debt" in b or "Debt" in b:
                            j["Debt Bondage"].append(1)
                        else:
                            j["Debt Bondage"].append(0)
                        if "sex" in b or "Sex" in b:
                            j["Sex Trafficking"].append(1)
                        else:
                            j["Sex Trafficking"].append(0)
                        if "force" in b or "Forced" in b:
                            j["Forced Labor"].append(1)
                        else:
                            j["Forced Labor"].append(0)
        x += 1
    df = pd.DataFrame.from_dict(j, orient='index').transpose()
    return df

# %%
a = get_dataframe(changed_countries,new_normal_countr,trafficking_profile)

# %%
a.sort_values(by=['Base Country']).reset_index(drop=True)
# Out:
#      Base Country      Relation Country Men Women Children Sex Trafficking  \
# 0     Afghanistan                 India   1     1        1               0
# 1     Afghanistan            Tajikistan   1     0        0               0
# 2     Afghanistan             Sri Lanka   1     0        0               0
# 3     Afghanistan              Pakistan   1     0        0               0
# 4     Afghanistan                 Nepal   1     0        0               0
# 5     Afghanistan                  Iran   1     0        0               0
# 6     Afghanistan                 India   1     0        0               0
# 7     Afghanistan            Tajikistan   0     1        1               1
# 8     Afghanistan             Sri Lanka   0     1        1               1
# 9     Afghanistan           Philippines   0     1        1               1
# 10    Afghanistan                  Iran   0     1        1               1
# 11    Afghanistan                 China   0     1        1               1
# 12    Afghanistan              Pakistan   0     1        1               1
# 13    Afghanistan                  Iran   1     0        1               0
# 14    Afghanistan                  Iran   1     1        1               0
# 15    Afghanistan              Pakistan   1     1        1               0
# 16    Afghanistan                 India   0     1        1               1
# 17    Afghanistan                 Syria   1     0        1               0
# 18    Afghanistan              Pakistan   0     1        1               1
# 19    Afghanistan                  Iran   0     1        1               1
# 20    Afghanistan                  Iran   1     0        1               0
# 21    Afghanistan              Pakistan   1     0        1               0
# 22    Afghanistan                Turkey   1     0        1               0
# 23    Afghanistan                Greece   0     0        1               1
# 24    Afghanistan                Greece   1     0        1               0
# 25        Albania                Kosovo   0     0        1               0
# 26        Albania        United Kingdom   0     0        1               0
# 27        Algeria               Nigeria   1     0        0               1
# 28        Algeria                 Niger   0     0        1               0
# 29        Algeria                 Niger   0     0        1               0
# ...           ...                   ...  ..   ...      ...             ...
# 1185        Yemen                  Oman   1     0        1               0
# 1186        Yemen              Ethiopia   1     0        1               0
# 1187        Yemen          Saudi Arabia   1     0        0               0
# 1188        Yemen              Djibouti   1     0        1               0
# 1189        Yemen          Saudi Arabia   1     0        0               0
# 1190        Yemen          Saudi Arabia   1     0        1               0
# 1191        Yemen                 Syria   0     1        1               1
# 1192        Yemen          Saudi Arabia   1     0        0               0
# 1193        Yemen              Ethiopia   0     1        1               1
# 1194        Yemen               Eritrea   0     1        1               1
# 1195        Yemen          Saudi Arabia   0     0        1               1
# 1196        Yemen          Saudi Arabia   1     0        1               0
# 1197        Yemen          Saudi Arabia   1     0        1               1
# 1198        Yemen          Saudi Arabia   1     0        1               1
# 1199        Yemen          Saudi Arabia   1     0        1               1
# 1200        Yemen  United Arab Emirates   1     0        1               1
# 1201       Zambia              Zimbabwe   0     1        1               1
# 1202       Zambia          South Africa   0     1        1               1
# 1203       Zambia              Zimbabwe   0     0        1               1
# 1204       Zambia              Tanzania   0     0        1               1
# 1205     Zimbabwe          South Africa   1     1        1               0
# 1206     Zimbabwe          South Africa   0     1        1               0
# 1207     Zimbabwe          South Africa   0     0        1               1
# 1208     Zimbabwe                 China   0     1        0               0
# 1209     Zimbabwe          Saudi Arabia   0     1        0               1
# 1210     Zimbabwe            Mozambique   0     0        1               0
# 1211     Zimbabwe                Zambia   0     1        1               1
# 1212     Zimbabwe          South Africa   0     1        1               1
# 1213     Zimbabwe            Mozambique   0     1        1               1
# 1214     Zimbabwe                Kuwait   0     1        0               1
#
#      Forced Labor Debt Bondage  \
# 0               1            0
# 1               1            0
# 2               1            0
# 3               1            0
# 4               1            0
# 5               1            0
# 6               1            0
# 7               0            0
# 8               0            0
# 9               0            0
# 10              0            0
# 11              0            0
# 12              0            0
# 13              0            0
# 14              1            0
# 15              1            0
# 16              1            0
# 17              0            0
# 18              1            0
# 19              1            0
# 20              1            1
# 21              1            1
# 22              1            1
# 23              0            0
# 24              1            1
# 25              1            0
# 26              1            0
# 27              0            0
# 28              1            0
# 29              1            0
# ...           ...          ...
# 1185            1            0
# 1186            0            0
# 1187            0            0
# 1188            0            0
# 1189            0            0
# 1190            0            0
# 1191            1            0
# 1192            0            0
# 1193            1            0
# 1194            1            0
# 1195            1            0
# 1196            1            0
# 1197            0            0
# 1198            0            0
# 1199            0            0
# 1200            0            0
# 1201            0            0
# 1202            0            0
# 1203            0            0
# 1204            0            0
# 1205            0            0
# 1206            1            0
# 1207            0            0
# 1208            0            0
# 1209            1            0
# 1210            1            0
# 1211            1            0
# 1212            1            0
# 1213            1            0
# 1214            1            0
#
#                                             Description
# 0      Men, women, and children in Afghanistan often...
# 1      Under the pretense of high-paying employment ...
# 2      Under the pretense of high-paying employment ...
# 3      Under the pretense of high-paying employment ...
# 4      Under the pretense of high-paying employment ...
# 5      Under the pretense of high-paying employment ...
# 6      Under the pretense of high-paying employment ...
# 7      There were reports of women and girls from th...
# 8      There were reports of women and girls from th...
# 9      There were reports of women and girls from th...
# 10     There were reports of women and girls from th...
# 11     There were reports of women and girls from th...
# 12     There were reports of women and girls from th...
# 13     Reportedly, the Iranian government and the Is...
# 14     Men, women, and children in Afghanistan often...
# 15     Men, women, and children in Afghanistan often...
# 16     Afghan women and girls are subjected to sex t...
# 17     Reportedly, the Iranian government and the Is...
# 18     Afghan women and girls are subjected to sex t...
# 19     Afghan women and girls are subjected to sex t...
# 20     Afghan boys and men are subjected to forced l...
# 21     Afghan boys and men are subjected to forced l...
# 22     Afghan boys and men are subjected to forced l...
# 23     Some Afghan boys are subjected to sex traffic...
# 24     Afghan boys and men are subjected to forced l...
# 25     NGOs report an increase in the number of Alba...
# 26     NGOs report an increase in the number of Alba...
# 27     Undocumented sub-Saharan migrants, primarily ...
# 28     Nigerien children, ranging from 4 to 8 years ...
# 29     Nigerien female migrants begging in Algeria, ...
# ...                                                 ...
# 1185   Past reports suggested some Yemeni childrenŠm...
# 1186   Reports suggest at least 150 migrants attempt...
# 1187   In past years, multiple NGOs reported crimina...
# 1188   Reports suggest at least 150 migrants attempt...
# 1189   Traffickers abused and abandoned in Yemen som...
# 1190   Yemeni and Saudi gangs transported African ch...
# 1191   The UN estimated that the protracted Syrian c...
# 1192   Prior to the conftict's escalation and the go...
# 1193   Ethiopians, Eritreans, and Somalis traveled v...
# 1194   Ethiopians, Eritreans, and Somalis traveled v...
# 1195   Traffickers, security officials, and employer...
# 1196   Past reports suggested some Yemeni childrenŠm...
# 1197  Yemeni children have been subjected to sex tra...
# 1198   Prior to the conftict, most child sex tourist...
# 1199   Some Saudi men used legally contracted ﬁtempo...
# 1200   Prior to the conftict, most child sex tourist...
# 1201   Zambian boys are subjected to sex trafficking...
# 1202   Zambian boys are subjected to sex trafficking...
# 1203   Zambian boys and girls are exploited in sex t...
# 1204   Zambian boys and girls are exploited in sex t...
# 1205   Men, women, and children, predominantly from ...
# 1206   Some Zimbabwean men, women, and children in S...
# 1207   Many Zimbabwean adult and child migrants ente...
# 1208   There were previous reports of Zimbabwean wom...
# 1209   Women are exploited in domestic servitude, fo...
# 1210   There were increased reports of children from...
# 1211   Women and girls from Zimbabwean towns borderi...
# 1212   Women and girls from Zimbabwean towns borderi...
# 1213   Women and girls from Zimbabwean towns borderi...
# 1214   Women are exploited in domestic servitude, fo...
#
# [1215 rows x 9 columns]

# %%
a.loc[a['Base Country']=="Nigeria"].reset_index(drop=True)
# Out:
#    Base Country      Relation Country Men Women Children Sex Trafficking  \
# 0       Nigeria                 Niger   0     1        1               1
# 1       Nigeria                 Niger   0     1        0               0
# 2       Nigeria            Cabo Verde   0     1        1               1
# 3       Nigeria         Cote d'Ivoire   0     1        1               1
# 4       Nigeria                  Mali   0     1        1               1
# 5       Nigeria                 Niger   0     1        1               1
# 6       Nigeria               Senegal   0     1        1               1
# 7       Nigeria          South Africa   0     1        1               1
# 8       Nigeria                 Niger   0     1        1               1
# 9       Nigeria                  Oman   0     1        1               1
# 10      Nigeria          Saudi Arabia   0     1        1               1
# 11      Nigeria  United Arab Emirates   0     1        1               1
# 12      Nigeria                 Niger   0     0        1               0
# 13      Nigeria                 Niger   0     1        0               0
# 14      Nigeria              Cameroon   0     0        1               0
# 15      Nigeria     Equatorial Guinea   0     0        1               0
# 16      Nigeria                 Gabon   0     0        1               0
# 17      Nigeria                Guinea   0     0        1               0
# 18      Nigeria                 Niger   0     0        1               0
# 19      Nigeria                 Niger   0     0        1               1
# 20      Nigeria                  Togo   0     0        1               1
# 21      Nigeria               Austria   0     1        1               1
# 22      Nigeria                 Italy   0     1        1               1
# 23      Nigeria                 Niger   0     1        1               1
# 24      Nigeria                Russia   0     1        1               1
# 25      Nigeria                 Spain   0     1        1               1
# 26      Nigeria                 Niger   1     0        0               0
# 27      Nigeria                 Italy   0     1        1               0
# 28      Nigeria                 Niger   0     1        1               0
# 29      Nigeria                 Niger   0     1        0               0
# 30      Nigeria                 Niger   1     0        0               0
# 31      Nigeria                 Libya   1     0        0               0
# 32      Nigeria                 Niger   1     0        0               0
# 33      Nigeria                 Libya   1     0        0               0
# 34      Nigeria                 Niger   0     1        1               1
# 35      Nigeria                 Libya   0     1        1               1
# 36      Nigeria                 Niger   0     1        1               1
# 37      Nigeria                 Niger   0     1        1               1
# 38      Nigeria                 Niger   0     0        1               1
# 39      Nigeria              Cameroon   0     0        1               0
# 40      Nigeria                  Chad   0     0        1               0
# 41      Nigeria                 Niger   0     0        1               0
# 42      Nigeria                 Niger   0     1        1               0
# 43      Nigeria                 Niger   0     0        1               0
# 44      Nigeria                 Niger   0     0        1               0
# 45      Nigeria                 Niger   0     0        1               0
# 46      Nigeria                 Niger   0     0        1               0
# 47      Nigeria                 Niger   1     0        1               0
# 48      Nigeria                 Niger   0     0        1               0
#
#    Forced Labor Debt Bondage  \
# 0             1            0
# 1             0            0
# 2             1            0
# 3             1            0
# 4             1            0
# 5             1            0
# 6             1            0
# 7             1            0
# 8             1            0
# 9             1            0
# 10            1            0
# 11            1            0
# 12            1            0
# 13            1            0
# 14            1            0
# 15            1            0
# 16            1            0
# 17            1            0
# 18            1            0
# 19            0            0
# 20            0            0
# 21            0            0
# 22            0            0
# 23            0            0
# 24            0            0
# 25            0            0
# 26            0            0
# 27            0            0
# 28            0            0
# 29            1            0
# 30            0            0
# 31            0            0
# 32            0            0
# 33            0            0
# 34            0            0
# 35            0            0
# 36            1            0
# 37            0            0
# 38            1            0
# 39            0            0
# 40            0            0
# 41            0            0
# 42            1            0
# 43            0            0
# 44            0            0
# 45            0            0
# 46            0            0
# 47            0            0
# 48            0            0
#
#                                           Description
# 0   As reported over the past five years, Nigeria ...
# 1    In southern Nigeria, especially Lagos, some w...
# 2    Nigerian traffickers take women and children ...
# 3    Nigerian traffickers take women and children ...
# 4    Nigerian traffickers take women and children ...
# 5    Nigerian traffickers take women and children ...
# 6    Nigerian traffickers take women and children ...
# 7    Nigerian traffickers take women and children ...
# 8    Nigerian women and children are recruited and...
# 9    Nigerian women and children are recruited and...
# 10   Nigerian women and children are recruited and...
# 11   Nigerian women and children are recruited and...
# 12   West African children are subjected to forced...
# 13   Women from West African countries transit Nig...
# 14   Nigeria's ports and waterways around Calabar ...
# 15   Nigeria's ports and waterways around Calabar ...
# 16   Nigeria's ports and waterways around Calabar ...
# 17   Nigeria's ports and waterways around Calabar ...
# 18   Nigeria's ports and waterways around Calabar ...
# 19     Nigerians travel to Togo for child sex tourism
# 20     Nigerians travel to Togo for child sex tourism
# 21   Nigerian women and girls are subjected to sex...
# 22   Nigerian women and girls are subjected to sex...
# 23   Nigerian women and girls are subjected to sex...
# 24   Nigerian women and girls are subjected to sex...
# 25   Nigerian women and girls are subjected to sex...
# 26   In 2015, a foreign government reported that w...
# 27   One local press report noted that traffickers...
# 28   One local press report noted that traffickers...
# 29   Before departure for work abroad, many Nigeri...
# 30   Some trafficking victims in Libya reported Ni...
# 31   Some trafficking victims in Libya reported Ni...
# 32   A foreign government estimated as many as 20,...
# 33   A foreign government estimated as many as 20,...
# 34   ISIS has captured Nigerian women and girls in...
# 35   ISIS has captured Nigerian women and girls in...
# 36   ﬁGatekeepersﬂ in control of some IDP camps, a...
# 37   In July 2016, a Nigerian research organizatio...
# 38   As previously reported by media, there were c...
# 39  Boko Haram and ISIS-WA continued to forcibly r...
# 40  Boko Haram and ISIS-WA continued to forcibly r...
# 41  Boko Haram and ISIS-WA continued to forcibly r...
# 42   The groups continue to abduct women and girls...
# 43   International organizations continue to expre...
# 44   As previously reported, the Nigerian military...
# 45   The Nigerian military interrogated children i...
# 46   As reported by the Secretary-General of the U...
# 47   The Nigerian military also conducted on-the-g...
# 48   As previously reported, CJTF has recruited ch...
