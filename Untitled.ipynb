# %%
import pandas as pd 
import numpy as np

# %%
Poverty = pd.read_csv("poverty.csv")

print(Poverty)
Poverty.head()
# Out:
#                                             Unnamed: 0  \
# 0                                          Afghanistan
# 1                                              Albania
# 2                                              Algeria
# 3                                       American Samoa
# 4                                              Andorra
# ..                                                 ...
# 253                                   General comments
# 254  The World Bank’s internationally comparable po...
# 255                                                NaN
# 256                                                NaN
# 257  Please see the online table at http://wdi.worl...
#
#     Population below $1.90 a day Population below $3.20 a day  \
# 0                             ..                           ..
# 1                            1.7                         10.4
# 2                            0.5                          3.9
# ...

# %%
Poverty.dropna()
# Out:
#                 Unnamed: 0 Population below $1.90 a day  \
# 0              Afghanistan                           ..
# 1                  Albania                          1.7
# 2                  Algeria                          0.5
# 3           American Samoa                           ..
# 4                  Andorra                           ..
# ..                     ...                          ...
# 211  Virgin Islands (U.S.)                           ..
# 212     West Bank and Gaza                            1
# 213            Yemen, Rep.                         18.8
# 214                 Zambia                         57.5
# 215               Zimbabwe                         33.9
#
#     Population below $3.20 a day Population below $5.50 a day
# 0                             ..                           ..
# 1                           10.4                           38
# 2                            3.9                         29.2
# ...

# %%
Cleaned_Poverty = Poverty.rename(columns= {'Unnamed: 0':'Country', 
                                    'Unnamed: 2':'% Pop. Below $1.90 per day',
                                    'Unnamed: 3':'% Pop. Below $3.20 per day',
                                    'Unnamed: 4':'% Pop. Below $5.50 per day'
                                   })
Cleaned_Poverty.head()
# Out:
#           Country Population below $1.90 a day Population below $3.20 a day  \
# 0     Afghanistan                           ..                           ..
# 1         Albania                          1.7                         10.4
# 2         Algeria                          0.5                          3.9
# 3  American Samoa                           ..                           ..
# 4         Andorra                           ..                           ..
#
#   Population below $5.50 a day
# 0                           ..
# 1                           38
# 2                         29.2
# 3                           ..
# 4                           ..

# %%
Cleaned_Poverty.to_json(r"Cleaned_Poverty_Data.json")
