# %%
import pandas as pd

# %%
df = pd.read_csv("../Adam/Resources/trafficking_report.csv")
df = df.T
df
# Out:
#                                                                    0     \
# Unnamed: 0                                                            0
# Base Country                                                Afghanistan
# Base Country Lat                                                33.9391
# Base Country Lng                                                  67.71
# Relation Country                                                  India
# Relation Country Lat                                            20.5937
# Relation Country Lng                                            78.9629
# Men                                                                   1
# Women                                                                 1
# Children                                                              1
# Sex Trafficking                                                       0
# Forced Labor                                                          1
# ...

# %%
df.to_json("trafficking.json")
