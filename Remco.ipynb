# %%
import pandas as pd
import pycountry

# %%
csv_human_trafficking = "human_trafficking_dataset.csv"
ht_data = pd.read_csv(csv_human_trafficking)

ht_data.head()
# Out:
# C:\Users\Remco\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (54) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    By using this data you agree to the Terms of Use: https://www.ctdatacollaborative.org/terms-use  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    yearOfRegistration       Datasource gender ageBroad majorityStatus  \
# 0                2002  Case Management    -99      -99            -99
# 1                2002  Case Management    -99      -99            -99
# 2                2002  Case Management    -99      -99            -99
# ...

# %%
ht_data.drop(ht_data.columns[[0]], axis=1, inplace=True)
ht_data.head()
# Out:
#    yearOfRegistration       Datasource gender ageBroad majorityStatus  \
# 0                2002  Case Management    -99      -99            -99
# 1                2002  Case Management    -99      -99            -99
# 2                2002  Case Management    -99      -99            -99
# 3                2002  Case Management    -99      -99            -99
# 4                2002  Case Management    -99      -99            -99
#
#   majorityStatusAtExploit majorityEntry citizenship  \
# 0                     -99           -99         -99
# 1                     -99           -99         -99
# 2                     -99           -99         -99
# 3                     -99           -99         -99
# 4                     -99           -99         -99
#
#    meansOfControlDebtBondage  meansOfControlTakesEarnings  ...  \
# 0                        -99                          -99  ...
# 1                        -99                          -99  ...
# ...

# %%
ht_data = ht_data.loc[ht_data["citizenship"] != "-99", :]
ht_data.head()
# Out:
#     yearOfRegistration       Datasource  gender ageBroad majorityStatus  \
# 13                2002  Case Management  Female   18--20          Adult
# 14                2002  Case Management  Female   18--20          Adult
# 15                2002  Case Management  Female   18--20          Adult
# 16                2002  Case Management  Female   18--20          Adult
# 17                2002  Case Management  Female   18--20          Adult
#
#    majorityStatusAtExploit majorityEntry citizenship  \
# 13                     -99           -99         COL
# 14                     -99           -99         COL
# 15                     -99           -99         COL
# 16                     -99           -99         COL
# 17                     -99           -99         COL
#
#     meansOfControlDebtBondage  meansOfControlTakesEarnings  ...  \
# 13                        -99                          -99  ...
# 14                        -99                          -99  ...
# ...

# %%
germany = pycountry.countries
for country in germany:
    print(country)
# Out:
# Country(alpha_2='AW', alpha_3='ABW', name='Aruba', numeric='533')
# Country(alpha_2='AF', alpha_3='AFG', name='Afghanistan', numeric='004', official_name='Islamic Republic of Afghanistan')
# Country(alpha_2='AO', alpha_3='AGO', name='Angola', numeric='024', official_name='Republic of Angola')
# Country(alpha_2='AI', alpha_3='AIA', name='Anguilla', numeric='660')
# Country(alpha_2='AX', alpha_3='ALA', name='Åland Islands', numeric='248')
# Country(alpha_2='AL', alpha_3='ALB', name='Albania', numeric='008', official_name='Republic of Albania')
# Country(alpha_2='AD', alpha_3='AND', name='Andorra', numeric='020', official_name='Principality of Andorra')
# Country(alpha_2='AE', alpha_3='ARE', name='United Arab Emirates', numeric='784')
# Country(alpha_2='AR', alpha_3='ARG', name='Argentina', numeric='032', official_name='Argentine Republic')
# Country(alpha_2='AM', alpha_3='ARM', name='Armenia', numeric='051', official_name='Republic of Armenia')
# ...

# %%
#Convert 2-letter country codes to 3-letter country codes
for index, row in ht_data.iterrows():
    citizenship = row["citizenship"]
    country = pycountry.countries.get(alpha_2=citizenship)
    try:
        ht_data.loc[index, "citizenship"] = country.alpha_3
    except AttributeError:
        pass

# %%
ht_data
# Out:
#        yearOfRegistration       Datasource  gender ageBroad majorityStatus  \
# 13                   2002  Case Management  Female   18--20          Adult
# 14                   2002  Case Management  Female   18--20          Adult
# 15                   2002  Case Management  Female   18--20          Adult
# 16                   2002  Case Management  Female   18--20          Adult
# 17                   2002  Case Management  Female   18--20          Adult
# ...                   ...              ...     ...      ...            ...
# 55429                2018  Case Management    Male      -99            -99
# 55430                2018  Case Management    Male      -99            -99
# 55431                2018  Case Management    Male      -99            -99
# 55432                2018  Case Management    Male      -99            -99
# 55433                2018  Case Management    Male      -99            -99
#
#       majorityStatusAtExploit majorityEntry citizenship  \
# ...

# %%
ht_data.to_json("human_trafficking.json")
